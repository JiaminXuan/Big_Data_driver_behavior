# %%
from pandas import DataFrame as df

# %%
cluster=df.from_csv('similardrivers.csv',index_col=None)
cluster.index=range(len(cluster.index))
cluster
# Out:
#                                                 cluster
# 0                       [12714 18296 24560 32634 34872]
# 1                        [5597 19334 29055 35934 41560]
# 2     [3881 7888 10824 17933 21751 22474 26868 27144...
# 3     [1124 2723 5014 5656 6360 9011 9295 9569 15188...
# 4     [8261 12794 18329 27060 31378 33106 33561 3490...
# 5                              [7060 14291 24930 28181]
# 6     [138 830 4492 7330 14917 14971 16965 20049 236...
# 7     [6707 8238 9027 9800 15213 22039 25141 25882 2...
# 8     [34 140 273 363 432 434 490 518 714 732 742 87...
# 9                             [10808 13127 16125 21045]
# 10    [587 4173 8845 9186 13506 13576 17647 18044 18...
# 11    [5393 13819 14647 16169 18761 19348 22180 2579...
# 12    [1212 1628 10034 11232 12123 13328 14505 15998...
# 13                                  [11686 11875 39957]
# 14    [2730 5881 6894 13542 16307 21663 22655 23076 ...
# 15    [114 700 1873 1951 2738 2890 6995 13430 14410 ...
# ...

# %%
cluster['cluster']=map(len,cluster['cluster'])
cluster.to_csv('cluster_size.csv')

# %%
cluster=df.from_csv('part-00000',sep='\t')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-34-56b8e2562228> in <module>()
# ----> 1 cluster=df.from_csv('part-00000',sep='\t')
#
# /Users/xuanjm/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in from_csv(cls, path, header, sep, index_col, parse_dates, encoding, tupleize_cols, infer_datetime_format)
#    1033                           parse_dates=parse_dates, index_col=index_col,
#    1034                           encoding=encoding, tupleize_cols=tupleize_cols,
# -> 1035                           infer_datetime_format=infer_datetime_format)
#    1036
#    1037     def to_sparse(self, fill_value=None, kind='block'):
#
# ...

# %%
cluster['hack']=cluster.index
cluster.index=range(len(cluster.index)+1)[1:]

# %%
cluster
# Out:
#                                                    hoods  \
# 1      033100,009800,009200,001800,003001,007900,0137...
# 2      071600,010100,008300,009200,005000,013700,0099...
# 3      010100,009200,009400,011300,014900,008200,0109...
# 4      033100,009800,003800,004100,004000,007600,UNKN...
# 5      003700,003300,009900,007200,003900,002900,0021...
# 6      010100,013100,013700,033100,012500,007900,0113...
# 7      007900,012500,010100,006500,013700,005800,0119...
# 8      010100,009200,011900,012500,007200,013100,0108...
# 9      010100,007900,003200,006500,013700,009900,0119...
# 10     010100,UNKNOWN,009200,009900,033100,004400,008...
# 11     010100,008300,007900,009900,013700,007100,0072...
# 12     033100,012500,011900,071600,010100,009900,0137...
# 13     010100,011900,009900,009200,UNKNOWN,007900,012...
# 14     007900,033100,006300,011202,009900,005400,0047...
# 15     014300,016300,017500,017100,014200,019900,0183...
# ...
