# %%
from pandas import DataFrame as df

# %%
evils=df.from_csv('evil-3')
evils
# Out:
#                                     evil-score
# driver
# 0002555BBE359440D6CEB34B699D3932    807.029954
# 0006C8F9279EFD18D8E70193D98499CB    277.155067
# 000894B0A4A38A167C23588A0F31864D     69.463991
# 0008B3E338CE8C3377E071A4D80D3694   5026.164669
# 000A4EBF1CEB9C6BD9978D4362493C6E    669.201293
# 000B8D660A329BBDBF888500E4BD8B98    711.035537
# 000C15EFBDF58CAED528C09E597484EC    558.081325
# 000CCA239BFDC0ABE2895AC9086C4290    471.054256
# 00117D7CCD47D125E77163A7AC2C66EB    630.052097
# 0011B1575B9F5398BBC0F27EA560D631    524.746632
# 0012175D1505490267F025EAD9416CDD    301.115560
# 0012703023AC1788D34F6694908900FC    901.062262
# 001755823155165E769E3CDFC7EAB87F    146.021185
# 0017F419EFB3AD085B282D1257D26B61      4.052859
# 00184958F5D5FD0A9EC0B115C5B55796    458.394540
# 001916B0A5713FF05D936EFF82EEBA02    728.348855
# 001B5364A9CAEC8250250BC05E28693D    100.982640
# 001B589A8CE9336B13431595AC15B718    451.369673
# 001C8AAB90AEE49F36FCAA7B4136C81A    606.656198
# ...

# %%
evils.sort(columns='evil-score',inplace=True,ascending=False)

# %%
# %matplotlib inline
evils.iloc[:100].plot()

# %%
len(evils.index)
# Out:
# 41457

# %%
evils.to_csv('sorted')

# %%
license=df.from_csv('/Users/xuanjm/Desktop/licenses.csv')

# %%
import pandas as pd
joined=evils.merge(license,right_index=True,left_index=True,how='left')

# %%
joined
# Out:
#                                      evil-score name type current_status  \
# driver
# ED00885FE0AA1310582E41B56F4A25E3  360811.103626  NaN  NaN            NaN
# 0B21B07994F53C937E2687A81488A3C5  335884.792532  NaN  NaN            NaN
# DE582DDF1211613CDF2EA7AA264B4EFF  323333.011896  NaN  NaN            NaN
# 0420EC44A00B1764DADD034981FC24D3  298233.450924  NaN  NaN            NaN
# 4530A615AFF3C45F5859B1E0733F5A1B  229706.344202  NaN  NaN            NaN
# EF34B2259B642B0CBC28066633F02BC8  179477.529333  NaN  NaN            NaN
# D4459260E05F8D5FA8719D9A8BDB34AF  141211.650287  NaN  NaN            NaN
# 178BA04DD1A4E3A184C86AA3F110A742  119752.637192  NaN  NaN            NaN
# 48FDF347BD793FD29896F98CF9C771A3  109778.219611  NaN  NaN            NaN
# 0242322FA30E9941315B3B682BFE7EFE   92741.645441  NaN  NaN            NaN
# 3B7B73272A6C0B67822A73BFD4DB9CC7   86796.873116  NaN  NaN            NaN
# B6ECE25BCAD997A1BCA7A5AEADCA4746   84932.437686  NaN  NaN            NaN
# ...
